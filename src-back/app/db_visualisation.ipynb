# %%
import pandas as pd
import sqlite3

# %%
try:
    conn = sqlite3.connect("broccolii.db")    
except Exception as e:
    print(e)

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(f"Table Name : {cursor.fetchall()}")
# Out:
# Table Name : [('Word',), ('sqlite_sequence',), ('Category',), ('Account',), ('Card',), ('CardEffect',), ('WordCategory',), ('AccountCard',), ('ExpiredToken',)]

# %%
word =  pd.read_sql_query("SELECT * FROM Word", conn)
word.head()
# Out:
#    id     word
# 0   1   carrot
# 1   2   potato
# 2   3     rice
# 3   4   tomato
# 4   5  cabbage

# %%
sqlite_sequence =  pd.read_sql_query("SELECT * FROM sqlite_sequence", conn)
sqlite_sequence
# Out:
#          name  seq
# 0     Account    5
# 1    Category    3
# 2        Word  998
# 3        Card   16
# 4  CardEffect   12

# %%
Category =  pd.read_sql_query("SELECT * FROM Category", conn)
Category
# Out:
#    id         name
# 0   1  Agriculture
# 1   2        Green
# 2   3      B_words

# %%
Account =  pd.read_sql_query("SELECT * FROM Account", conn)
Account
# Out:
#    id  broccolis     username  \
# 0   1          0     Alettuce
# 1   2          0  Brocolivier
# 2   3          0     Picorims
# 3   4          0        Ar-No
# 4   5          0    Maximator
#
#                                             password
# 0  $2b$12$pkyrX.mR3hIr6dmB5825W.eHZALrUA.ntJAbtER...
# 1  $2b$12$k3HQy2Fe7a4JBZQVOseP7Ouot8jqDTcdBjLfNW/...
# 2  $2b$12$Y9UT8yD83z1T0/eq6v9RQ.K1dcjJVAzkQga7lJI...
# 3  $2b$12$tb0yAk5c3rKBI9nuxpZ.eOrpQVoZ4il4tdbnUXh...
# 4  $2b$12$3tiTxYfWB/mZXiSAh87WO.SVqpE3KHJcX.3r1A1...

# %%
Card =  pd.read_sql_query("SELECT * FROM Card", conn)
Card
# Out:
#     id        name                                             effect  \
# 0    1      Farmer  Will add 1 broccoli to your account every seco...
# 1    2      Farmer  Will add 1 broccoli to your account every seco...
# 2    3  Super soil      Will multiply your broccoli production by 2 !
# 3    4  Super soil      Will multiply your broccoli production by 2 !
# 4    5      Farmer  Will add 1 broccoli to your account every seco...
# 5    6      Farmer  Will add 1 broccoli to your account every seco...
# 6    7  Super soil      Will multiply your broccoli production by 2 !
# 7    8  Super soil      Will multiply your broccoli production by 2 !
# 8    9    Eggplant            Will multiply your click effects by 2 !
# 9   10    Eggplant            Will multiply your click effects by 2 !
# 10  11      Carrot       Your clicks will now give 5 more broccolis !
# 11  12      Carrot       Your clicks will now give 5 more broccolis !
# ...

# %%
CardEffect =  pd.read_sql_query("SELECT * FROM CardEffect", conn)
CardEffect
# Out:
#     id  idEffect                     name  value
# 0    1         1        Add To Production   1.00
# 1    2         1        Add To Production   2.00
# 2    3         2             Add To Click   1.00
# 3    4         2             Add To Click   5.00
# 4    5         3   Multiply Production By   2.00
# 5    6         3   Multiply Production By   3.00
# 6    7         4       Multiply Clicks By   2.00
# 7    8         4       Multiply Clicks By   3.00
# 8    9         5       Add To Crit Chance   0.10
# 9   10         5       Add To Crit Chance   0.25
# 10  11         6  Multiply Crit Chance By   2.00
# 11  12         6  Multiply Crit Chance By   3.00

# %%
WordCategory =  pd.read_sql_query("SELECT * FROM WordCategory", conn)
WordCategory
# Out:
#      idWord  idCategory
# 0       208           1
# 1       260           1
# 2        61           1
# 3       396           1
# 4       116           1
# ..      ...         ...
# 880     903           3
# 881     956           3
# 882     942           3
# 883     812           3
# 884     827           3
#
# [885 rows x 2 columns]

# %%
AccountCard =  pd.read_sql_query("SELECT * FROM AccountCard", conn)
AccountCard
# Out:
# Empty DataFrame
# Columns: [idAccount, idCard, isEquipped]
# Index: []

# %%
cards = pd.read_sql_query("""SELECT c.id, c.name, effect, rarity, isNegative, ce.name, ce.value
            FROM Card c, CardEffect ce
            WHERE c.idCardEffect = ce.id;""", conn)

# %%
cards.to_pickle('cards.pkl')

# %%
cards.columns
# Out:
# Index(['id', 'name', 'effect', 'rarity', 'isNegative', 'name', 'value'], dtype='object')

# %%
cards.columns = ['id', 'name', 'effect', 'rarity', 'isNegative', 'effectType', 'value']

# %%
cards['effectType']
# Out:
# 0           Add To Production
# 1           Add To Production
# 2          Multiply Clicks By
# 3          Multiply Clicks By
# 4      Multiply Production By
# 5      Multiply Production By
# 6                Add To Click
# 7                Add To Click
# 8          Add To Crit Chance
# 9          Add To Crit Chance
# 10    Multiply Crit Chance By
# 11    Multiply Crit Chance By
# Name: effectType, dtype: object

# %%
import classes.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import classes.py
#
# File c:\Users\olivi\brocco2\app5-broccolii\src-back\app\classes.py:3
#       1 # -*- coding: utf-8 -*-
#       2 import sqlite3
# ----> 3 import bcrypt
#       4 from datetime import datetime
#       5 from .auth.jwt_utils import generate_refresh_token_timestamp
#
# ModuleNotFoundError: No module named 'bcrypt'

# %%
user =
